# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/crash-dataset-2016-2023/crash_data.csv',low_memory=False)

df.describe()
# Out:
#          Speed Limit   Vehicle Year       Latitude      Longitude
# count  172105.000000  172105.000000  172105.000000  172105.000000
# mean       32.549752    1966.306946      39.083119     -77.112343
# std        11.059987     340.615468       0.072032       0.098571
# min         0.000000       0.000000      37.720000     -79.486000
# 25%        25.000000    2006.000000      39.024417     -77.189327
# 50%        35.000000    2011.000000      39.074933     -77.105412
# 75%        40.000000    2015.000000      39.139742     -77.039592
# max        75.000000    9999.000000      39.990414     -75.527708

# %%
date_format = '%m/%d/%Y %I:%M:%S %p'

# Convert to datetime
df['Crash Date/Time'] = pd.to_datetime(df['Crash Date/Time'], format=date_format)

# %%
df['Year'] = df['Crash Date/Time'].dt.year
df['Month'] = df['Crash Date/Time'].dt.month

# %%
# Aggregate accidents per year to analyze yearly trend
yearly_accidents = df_filtered.groupby('Year').size().reset_index(name='Accidents')

# Visualize yearly accident trends
plt.figure(figsize=(8, 4))
plt.plot(yearly_accidents['Year'], yearly_accidents['Accidents'], marker='o')
plt.title('Yearly Accident Trends (2016-2023)')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.grid(True)
plt.show()

# %%
df_2019 = df[df['Year'] == 2019]

# %%
# Group by weather and count accidents
impact_counts = df_2019['Vehicle First Impact Location'].value_counts().reset_index()
impact_counts.columns = ['Vehicle First Impact Location', 'Accident Count']

# %%
# Plot the results
plt.figure(figsize=(10, 6))
sns.barplot(x='Vehicle First Impact Location', y='Accident Count', data=impact_counts, palette='viridis')
plt.title('Number of Accidents by Vehicle First Impact Location in 2019')
plt.xlabel('Impact Location')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()
